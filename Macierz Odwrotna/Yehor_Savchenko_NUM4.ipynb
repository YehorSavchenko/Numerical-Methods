# %% [markdown]
# Savchenko Yehor, Metody Numeryczne, zadanie NUM 4
#
# # **Instrukcja do programy:**
#
#
#
# 1.   Zainstalować python: https://www.python.org/downloads/
# 2.   Zainstalować biblioteki NumPy: `pip install numpy`
# 3.   Wpisać do terminalu: `python “FileName”`

# %% [markdown]
# # **Wstęp:**
#
# Miałem podane macierz `A` rozmiarem `N x N`.  Macierz A ma liczby 10 na diagonali, 8 na pierwszej pozycji nad diagonalą, a
# pozostałe elementy są równe 1.
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# oraz $\mathrm b = {(5,...,5)}^{T}$.  Rozmiar `N = 50`.
#
# Musiałem rozwiązać równanie $\mathrm Ay=b $ dla macierzy `A`. Zrobić to trzeba było włąściwą metodą i wykorzystać strukturę macierzy.
#
# Macierz `A` przedstawiam jako $\mathrm A' + u{v}^{T}$, gdzie macierz $\mathrm A' $ ma liczby 9 na diagonali, 7 na pierwszej pozycji nad diagonalą, a
# pozostałe elementy są równe 0. Wektor $\mathrm u \ i \ {v}^{T} $ są wektorami jedynek. W końcu mam równanie $\mathrm (A' + u{v}^{T})y=b $
#
#
#
# Dla sprawdzania wyników używałem bibliotek `numpy` i `scipy`.

# %% [markdown]
# # **Prezentacja wyników:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Przedyskutowanie wyników:**
#
# Dla otrzymania tych wyników przekształciłem równanie  $\mathrm (A' + u{v}^{T})x = b$ do postaci  $\mathrm x = {A'}^{-1}b - (({A'}^{-1}u{v}^{T}{A'}^{-1}b)/(1+{v}^{T}{A'}^{-1}u))$
#
#
# Zamieniłem  $\mathrm {A'}^{-1}b = z ; \  {A'}^{-1}u = z'$
#
#
# I miałem wzór na $\mathrm x = z - (z'({v}^{T}z)/(1+{v}^{T}z')$
#
# Z przekształceń wynika , że $\mathrm A'z=b; \ A'z'=u$
#
# Te 2 równania można rozwiązać metoda `LU`, ale przez to , że mamy tylko diagonalne i nad diagonale elementy , będziemy mieć tylko macierz `U`
#
# I równania już mają taką postać: $\mathrm Uz=b; \ Uz'=u$
#
# A te dwa równania możemy rozwiązać już metodą `backsubstitution`, otrzymać wektory `z` i `z'` i ostatnie podstawić do wzoru, który otrzymałem wcześniej.
#
# Wszystkie wyniki porównałem z wynikami uzyskanymi przy użyciu bibliotek algebraicznych.
